# %%
# !pip uninstall googletrans

# %%
import tensorflow as tf

from gensim.models.keyedvectors import KeyedVectors
from konlpy.tag import Mecab

from googletrans import Translator

import time
import numpy as np

import os
import sys
import urllib.request
import requests
import datetime
import pickle
import json

# %%
m = Mecab()

# %%
def embedding_load():
    """
    Load pretrained embedding vec
    """
    en_model = KeyedVectors.load_word2vec_format('./fasttext/wiki.en.vec')
    ko_model = KeyedVectors.load_word2vec_format('./fasttext/wiki.ko.vec')
    
    return en_model, ko_model

def get_translate(text, lan, c_id, c_key):
    data = {'text' : text,
            'source' : 'ko',
            'target': lan}

    url = "https://openapi.naver.com/v1/papago/n2mt"

    header = {"X-Naver-Client-Id":c_id,
              "X-Naver-Client-Secret":c_key}

    response = requests.post(url, headers=header, data= data)
    rescode = response.status_code

    if(rescode==200):
        t_data = response.json()
        return t_data['message']['result']['translatedText']
    else:
        print("Error Code:" , rescode)

def proper_noun(ko_model, method=None):
    """
    
    """
    tic = time.time()
    print(f'Proper_noun extract process start')
    print(f'Method selected : {method}')
    
    ko_noun = [i for i in list(ko_model.vocab) if m.pos(i)[0][1] == 'VV' and len(i) > 1]
    ko_noun_sample = ko_noun[:3000]
    
    en_noun = []
    
    if method == "google trans":
        translator = Translator()
        for i in ko_noun_sample:
            en_noun.append(translator.translate(i, src='ko', dest='en').text)

            time.sleep(1)
    
    elif method == "naver papago":
        client_id = 'Np0XYEpo30dZjQ4CwKjo'
        client_secret = 'l6CQ7zor3F'
        
        for i in ko_noun_sample:
            """
            if API requests exceeds the allowed, return None
            """
            try: 
                en_noun.append(get_translate(i, 'en', client_id, client_secret).lower())
            except:
                pass
    
    tok = time.time()
    tictok = str(datetime.timedelta(seconds=tok-tic))
    print(f'Proper_noun extract process end. Time spend : {tictok}')
    
    return ko_noun_sample, en_noun

def add_vocab(source, ko_dict, en_dict, method=None):
    
    
    if method == "google trans":
        translator = Translator()
        for i in ko_noun_sample:
            en_noun.append(translator.translate(i, src='ko', dest='en').text)

            time.sleep(1)
    
    elif method == "naver papago":
        client_id = 'Np0XYEpo30dZjQ4CwKjo'
        client_secret = 'l6CQ7zor3F'
        
        for i in source:
            """
            if API requests exceeds the allowed, return None
            """
            try: 
                en_noun.append(get_translate(i, 'en', client_id, client_secret).lower())
            except:
                pass

# %%
en_model, ko_model = embedding_load()

# %%
result = translator.translate('안녕하세요.', dest="ja")

# %%
translated_obj = translator.translate('한국의', src='ko', dest='en')
print(translated_obj.text)
# Out:
# 한국의

# %%
en_noun = [translator.translate(i, src='ko').text for i in list(ko_noun)[:10]]

# %%
en_noun
# Out:
# ['대한민국의', '미국의', '일본', '대한민국', '미국', '올림픽', '등의', '서울', '위키백과', '한국']

# %%
translator.translate('안녕', src='ko', dest='en').text
# Out:
# '안녕'

# %%
ko_noun_sample, en_noun_sample = proper_noun(ko_model, method='naver papago')
# Out:
# Proper_noun extract process start
# Method selected : naver papago
# Proper_noun extract process end. Time spend : 0:06:19.501213

# %%
len(ko_noun_sample), len(en_noun_sample)
# Out:
# (1999, 1999)

# %%
ko_dict = {}
en_dict = {}

# %%
# ko_noun_sample_add1, en_noun_sample_add1 = proper_noun(ko_model, method='naver papago')
# Out:
# Proper_noun extract process start
# Method selected : naver papago
# Proper_noun extract process end. Time spend : 0:05:28.952735

# %%
with open('./data/ko_noun_dict.pkl', "rb") as f:
    ko_dict = pickle.load(f)
    
with open('./data/en_noun_dict.pkl', "rb") as f:
    en_dict = pickle.load(f)

# %%
if (len(ko_dict) and len(en_dict)):
    print('add')
    for i in range(len(ko_noun_sample_add1)):
        try:
            en_dict[en_noun_sample_add1[i]] = en_model.get_vector(en_noun_sample_add1[i])
            ko_dict[ko_noun_sample_add1[i]] = ko_model.get_vector(ko_noun_sample_add1[i])
            
        except:
            pass
    
else:
    ko_dict = {}
    en_dict = {}
    for i in range(len(en_noun_sample)):
        try: 
            tmp = len(en_dict)
            en_dict[en_noun_sample[i]] = en_model.get_vector(en_noun_sample[i])
            if len(en_dict) == tmp:
                print(en_noun_sample[i])
            else:
                ko_dict[ko_noun_sample[i]] = ko_model.get_vector(ko_noun_sample[i])

        except:
            pass
# Out:
# matsumoto
# kobayashi
# china
# korean
# northwest
# albert
# cloud
# russia
# hideyoshi
# kazakhstan
# adam
# england
# kimura
# joseon
# lawrence
# solidarity
# hitler
# china
# dragons
# takeshi
# organizing
# uzbekistan
# girls
# valley
# russia
# wiki
# robert
# times
# manhattan
# cameroon
# benjamin
# alfred
# laos
# india
# joseph
# silla
# dragons
# albert
# fighters
# bangladesh
# matsuda
# samuel
# lebanon
# montenegro
# japanese
# tachibana
# jonathan
# union
# matsui
# guatemala
# kikuchi
# bird
# northwest
# margaret
# venice
# italy
# angola
# venus
# forefather

# %%
len(en_dict), len(ko_dict)
# Out:
# (1250, 1250)

# %%
ko_dict = {}
en_dict = {}

# %%
with open(f'./data/ko_noun_dict(vocab_size-{len(ko_dict)}).pkl', "wb") as fp:
    pickle.dump(ko_dict, fp)

with open(f'./data/en_noun_dict(vocab_size-{len(en_dict)}).pkl', "wb") as fp:
    pickle.dump(en_dict, fp)

# %%
np.save('ko_dict.npy', ko_dict)
np.save('en_dict.npy', en_dict)

# %%
list(ko_dict.values())[0]
# Out:
# array([-0.2348   ,  0.16632  , -0.42928  , -0.18025  , -0.15354  ,
#        -0.16659  , -0.11349  , -0.19434  , -0.27161  , -0.14352  ,
#         0.0027943,  0.06654  ,  0.1639   , -0.039142 , -0.051727 ,
#         0.0071263,  0.21649  , -0.070307 , -0.042044 , -0.2936   ,
#        -0.11884  ,  0.15512  , -0.084749 , -0.24455  , -0.12771  ,
#        -0.34986  ,  0.36895  , -0.0077137,  0.13818  , -0.1575   ,
#         0.055542 ,  0.047616 ,  0.33078  , -0.67881  , -0.38748  ,
#        -0.19999  ,  0.16253  , -0.21847  ,  0.0037893,  0.016311 ,
#        -0.18195  , -0.21904  ,  0.056312 , -0.25407  , -0.377    ,
#         0.55629  ,  0.19335  , -0.20228  ,  0.21381  ,  0.0072553,
#         0.59345  ,  0.29593  , -0.24016  ,  0.038687 ,  0.1417   ,
#        -0.054895 ,  0.53077  , -0.63831  ,  0.361    ,  0.017163 ,
#        -0.20676  , -0.11882  ,  0.092218 , -0.21871  ,  0.1988   ,
#         0.27376  ,  0.12984  , -0.0070696, -0.10353  , -0.048058 ,
#         0.36725  , -0.25155  ,  0.10473  , -0.39012  , -0.4601   ,
#        -0.022259 ,  0.1876   ,  0.063368 , -0.016911 ,  0.13848  ,
#         0.018386 ,  0.095421 , -0.1722   , -0.49055  , -0.084209 ,
#         0.080943 ,  0.35201  , -0.17556  ,  0.097893 ,  0.60714  ,
#         0.391    ,  0.42242  , -0.10521  ,  0.36318  ,  0.02255  ,
#         0.25022  , -0.15346  , -0.39287  ,  0.18993  ,  0.045498 ,
#        -0.21419  , -0.85623  ,  0.28085  ,  0.32206  ,  0.065386 ,
#         0.4315   ,  0.019912 , -0.33114  ,  0.18995  , -0.27394  ],
#       dtype=float32)

# %%
ko_dict = {}
en_dict = {}
for i in range(len(en_noun_sample)):
    try: 
        tmp = len(en_dict)
        en_dict[en_verb_sample[i]] = en_model.get_vector(en_verb_sample[i])
        if len(en_dict) == tmp:
            print(en_noun_sample[i])
        else:
            ko_dict[ko_verb_sample[i]] = ko_model.get_vector(ko_verb_sample[i])

    except:
        pass
# Out:
# stone
# ecuador
# hamilton
# columbia
# rio de janeiro
# manhattan
# namwon city
# hokuriku
# digimon
# obama
# italian descent
# sicily
# miyuki
# creative
# benedictine
# soccer
# layuku
# arabia
# roy
# yamazaki
# victor
# do a
# old
# joseph
# wolfgang
# dokdo
# mokpo city
# thrown away
# films
# yoshino
# roberto
# eva!
# northeast
# yokosuka
# reign
# raphael
# mexico city
# jessica
# times
# carter
# yunnan
# in china
# to france
# lyon
# boys
# korean professional baseball
# play
# arsenal
# mr. jang
# stopover
# lawrence
# troy
# arkansas
# alexandria
# ogawa
# batman
# anycall
# organizing
# korean
# kim kyu-sik
# northwest
# bangladesh
# daily
# dreamworks
# gag concert.
# uruguayan
# ikebukuro
# lena
# kenyan
# wiz
# newton
# wow
# in korea,
# emmy award
# son dong-kwon
# lucy
# place as well
# malta
# wimbledon
# edinburgh
# mr. shin
# albert
# litres
# ayaka
# hideyoshi
# larry
# kid
# it's
# division
# joshu
# mega
# europe
# choice
# storm
# lobby
# people's army of korea
# yusuke
# lithuanian
# julia.
# united arab emirates
# soviet army
# scandinavia
# champions
# morioca
# matsuyama
# cozima
# shinagawa
# ronald
# disputed
# shimonoseki
# hideyoshi
# platinum
# cube
# kazakhstan
# zagreb
# kyoko
# southwest
# slovak
# umeda
# england
# porto
# salerno
# nakdonggang river
# dalian
# eurasia
# dangjin time
# northern ireland
# in the southeast
# guro-gu
# pusan national university
# in daejeon
# jungang-dong
# secretary of japan
# mugunghwa lake
# democratic republican party
# descending mountain
# three musketeers
# glen
# yuuki
# pippin
# robinson
# amy
# solidarity
# kuraki
# mumbai
# in shanghai
# the essence
# fred
# riyadh
# mining district
# augustus
# jamie
# moroccan
# in london
# yeungnam university
# masato
# shuaisha
# inazuma
# tsubasa
# lion
# yongin city
# north korea
# hayato
# jesus
# nishitetsu
# hyori
# chosun university
# alarm bells
# brad.
# mixing
# soviet army
# nord
# kenichi
# the hague
# kadokawa
# lauren
# aragon
# della
# users
# miracle
# aria
# song si yeol
# law firm
# shiraish
# basic
# alberta
# to be a professional gamer
# regimental
# sayuri
# casino
# hirata
# western europe
# director
# chaos
# twin
# in korea,
# newton's
# parameters
# it's tetsuya
# ed
# akashi
# jefferson
# clear
# high-speed railway
# raina
# kawagoe
# mariko
# sheffield
# floor
# handled leek
# in beijing
# wataru
# toyota
# herbert
# senegal
# jongno-gu
# memphis
# screenplay
# next
# music award
# verona
# ouchi
# kim gu
# hertha
# yayoi
# count
# tanzania
# todd
# in tokyo
# peace and peace
# definition
# damage
# montgomery
# nishinomiya
# don't
# santos
# pyongyang direct city
# asan
# to italy
# mountain
# electric
# boca
# ieyasu
# university
# elliot
# margaret
# nights
# broadway
# the democratic party is
# beirut
# king gojong
# namnose
# pascal
# fantastic
# guinness
# geumgang
# tomoto
# winston
# rogers
# potter and
# lee know
# quest
# wyoming
# akihito
# guillaume
# wi-fi
# lee is
# kameyama
# only
# matsuda
# mainz
# jeju city
# sasebo
# silla
# new guinea
# yeongnam
# u.s. military government
# soviet union
# frederick
# ahn jung-geun
# molise
# dongdaemun
# million
# match fixing
# pyeongchang
# ishihara
# abelino
# gaycho
# now dong
# foreign ministry
# oyama
# nixon
# sienna
# gonzales
# andes
# mets
# firefox
# trek
# national history compilation committee
# takuya
# shunsuke
# mr. ryu
# kim jeon il
# ministry of foreign affairs and trade
# uni polyester
# manami
# blackburn
# new delhi
# etchzen
# hitoshi
# silla
# twenty
# voyager
# nonsan
# japanese version
# kuril
# yoshio
# forest
# edwin
# kotaro
# volga
# seoul and
# ricky
# transplant
# hottory
# freddy
# czechoslovakia
# bucheon-si city
# disco
# damascus
# san antonio
# orléan
# inigma
# matsuda
# around the time
# valerie
# tomomi
# shoko
# aristotle's
# matthew.
# montenegro
# english descent
# cajun
# luzon
# crete
# amano
# korean version
# richmond
# jungnang district
# swansea
# norman
# spanish
# heungseon daewongun
# benfica
# bradley
# song jin woo
# caseke
# nagato
# mt. baekdu.
# kim il sung
# daegu metropolitan office of education
# osan city
# los angeles
# heroes'
# eto
# we've got wikipedia, too.
# korean troops
# mr. kwon
# venice
# deokjin-gu
# ricardo.
# kikuchi
# primera liga
# hiroaki
# northwest
# scottish descent
# bohemia
# ooshima
# honolulu
# shock
# thunderstorm
# italy
# siheung county
# park jung hwan
# homeplus
# tsuyoshi
# it's a child
# venus
# busan city
# yosuke
# perugia
# forefather
# hirosaki
# hiroko
# in germany
# nakata
# ako
# yuri nose
# seo jae-pil is

# %%
len(ko_dict), len(en_dict)
# Out:
# (547, 547)

# %%
def get_noun_data(ko_dict, en_dict):
    for i in range(len(ko_dict)):
        ko_vector = list(ko_dict.values())[i]
        en_vector = list(en_dict.values())[i]
        
#         yield (ko_word, ko_vector, en_word, en_vector)
        yield (ko_vector, en_vector)
    
def get_noun_data_2(ko_vec, en_vec):
    for i in range(len(ko_vec)):
#         -2.3252e-01, -3.0705e-01, -1.0517e-01,  4.9428e-01, -1.9124e-01,
#          1.1929e-01,  4.5211e-02, -2.0592e-01,  8.2783e-02,  2.6686e-01,
#          3.8932e-01,  3.0137e-01,  2.7935e-02,  7.6626e-02,  8.0591e-02,
#         -1.7228e-01,  1.3917e-01, -4.5914e-02,  1.3949e-01,  1.7192e-01,
#         -1.0865e-01,  4.2163e-01,  1.3456e-01, -2.8841e-02,  7.7871e-02,
#          1.3395e-01, -3.1890e-01, -8.0554e-02,  3.1202e-01,  1.3109e-01,
#          3.1024e-01,  2.7055e-01,  1.5010e-01, -1.0647e-01,  1.3359e-01,
#          4.1551e-01,  3.4962e-01,  1.9734e-01,  2.0257e-01,  5.5784e-01,
#         -2.8603e-01, -4.2326e-02,  2.7780e-01, -2.1109e-01, -3.7050e-01,
#         -9.2742e-02,  3.8481e-03,  5.0462e-01,  4.2018e-01, -1.6981e-01,
#         -9.4061e-02, -1.8785e-01, -2.3779e-01, -7.7147e-02,  1.0325e-02,
#          9.0652e-02, -1.8029e-01,  1.7065e-01, -4.7728e-02, -3.5796e-02,
#         -1.1494e-01,  6.3033e-01,  1.0139e-01,  6.7471e-02,  3.0453e-01,
#          2.2438e-01, -2.2147e-01,  3.4278e-01, -1.0598e-01,  4.7833e-01,
#          1.4666e-01,  1.0379e-01,  4.2018e-01,  8.3425e-02, -4.3787e-01,
#         -1.0404e-01,  1.5555e-01,  2.6603e-01, -1.7047e-01, -2.0729e-01],
#        dtype=float32))

# %%
dataset = tf.data.Dataset.from_generator(get_noun_data_2, 
                              (tf.float64, tf.float64),
                              (tf.TensorShape([300]), tf.TensorShape([300])),
                               args=(list(ko_dict.values()), list(en_dict.values())))

# %%
ko_verb_sample, en_verb_sample = proper_noun(ko_model, method='naver papago')
# Out:
# Proper_noun extract process start
# Method selected : naver papago
# Error Code: 504
# Error Code: 504
# Error Code: 504
# Proper_noun extract process end. Time spend : 0:10:23.827025

# %%
ko_verb_sample, en_verb_sample
# Out:
# (['되었다',
#   '하는',
#   '보기',
#   '살아있는',
#   '하고',
#   '하였다',
#   '하지만',
#   '되어',
#   '가지고',
#   '않고',
#   '않은',
#   '되는',
#   '받았다',
#   '하여',
#   '않았다',
#   '않는다',
#   '따르면',
#   '되고',
#   '하지',
#   '하며',
#   '들어',
#   '받아',
#   '위하여',
#   '받은',
#   '대하여',
#   '보다',
#   '받고',
#   '보고',
#   '하다',
#   '되었고',
#   '두고',
#   '보면',
#   '갖고',
#   '않습니다',
#   '알고',
#   '되지',
#   '죽은',
#   '만들어',
#   '의하여',
#   '주는',
#   '불리는',
#   '않다',
#   '하면',
#   '않아',
#   '만드는',
#   '의하면',
#   '맡았다',
#   '가는',
#   '남아',
#   '하기',
#   '가리키는',
#   '나오는',
#   '쓰는',
#   '더불어',
#   '하는데',
#   '하게',
#   '보는',
#   '보이는',
#   '되었으며',
#   '사는',
#   '통하여',
#   '되면',
#   '받는',
#   '인하여',
#   '하면서',
#   '주었다',
#   '닫는',
#   '만들었다',
#   '자는',
#   '살고',
#   '맡고',
#   '되면서',
#   '이끄는',
#   '쓰이는',
#   '쓰고',
#   '타고',
#   '받지',
#   '부르는',
#   '하였고',
#   '이끌고',
#   '나타내는',
#   '이르는',
#   '하자',
#   '않으며',
#   '않으면',
#   '되며',
#   '잇는',
#   '받을',
#   '알게',
#   '가서',
#   '가지는',
#   '않게',
#   '얻었다',
#   '하였으나',
#   '남은',
#   '받게',
#   '넘는',
#   '되자',
#   '둘러보기',
#   '않았고',
#   '말았다',
#   '듣고',
#   '보아',
#   '하였으며',
#   '보이지',
#   '높이는',
#   '놓고',
#   '갖는',
#   '않지만',
#   '받는다',
#   '들고',
#   '만들고',
#   '들면',
#   '주고',
#   '얻을',
#   '번길',
#   '얻은',
#   '되는데',
#   '바뀌었다',
#   '지니고',
#   '죽었다',
#   '나타나는',
#   '보니',
#   '일어나는',
#   '맡은',
#   '받았고',
#   '다루는',
#   '하기도',
#   '이루고',
#   '하더라도',
#   '두었다',
#   '입고',
#   '되기',
#   '만들어졌다',
#   '오는',
#   '맡아',
#   '찾아',
#   '갖추고',
#   '만들기',
#   '않기',
#   '이루어졌다',
#   '얻어',
#   '나누어',
#   '맞는',
#   '이루는',
#   '앞두고',
#   '남구',
#   '받았으며',
#   '모르는',
#   '맞아',
#   '이르렀다',
#   '거두었다',
#   '맞지',
#   '따서',
#   '보았다',
#   '가도',
#   '아는',
#   '가고시마',
#   '되기도',
#   '관하여',
#   '보이고',
#   '하겠습니다',
#   '막기',
#   '담고',
#   '열리는',
#   '나뉘어',
#   '이르러',
#   '갖게',
#   '찾을',
#   '빛의',
#   '잡고',
#   '갖는다',
#   '하던',
#   '부르기도',
#   '흐르는',
#   '않을까요',
#   '타는',
#   '되었는데',
#   '않도록',
#   '찾는',
#   '먹는',
#   '넘어',
#   '맞게',
#   '하거나',
#   '죽자',
#   '않았지만',
#   '맺고',
#   '되었다고',
#   '하다가',
#   '담은',
#   '않았던',
#   '찾기',
#   '이끌었다',
#   '이어지는',
#   '쓰지',
#   '넣어',
#   '죽고',
#   '다루고',
#   '가지의',
#   '되었으나',
#   '잃고',
#   '불리며',
#   '지나지',
#   '생기는',
#   '붙어',
#   '접하고',
#   '얻게',
#   '받으며',
#   '마치고',
#   '보이며',
#   '삼아',
#   '않는다고',
#   '따르는',
#   '데리고',
#   '들어서',
#   '가지게',
#   '읽기',
#   '않았으며',
#   '불리기도',
#   '않음',
#   '버리고',
#   '쓰이고',
#   '보지',
#   '이르기까지',
#   '들어가는',
#   '세우고',
#   '모르겠습니다',
#   '지내고',
#   '삼았다',
#   '맺었다',
#   '움직이는',
#   '나오지',
#   '잃은',
#   '얻는',
#   '입었다',
#   '일으키는',
#   '먹는다',
#   '보내는',
#   '삶의',
#   '미치는',
#   '읽는',
#   '열었다',
#   '붙은',
#   '뛰고',
#   '말고',
#   '죽을',
#   '않다고',
#   '올리는',
#   '받기도',
#   '삼고',
#   '되었지만',
#   '바꾸었다',
#   '지었다',
#   '그러면',
#   '들었다',
#   '바꾸는',
#   '하였는데',
#   '부르고',
#   '부르며',
#   '놓은',
#   '않았습니다',
#   '먹고',
#   '떨어지는',
#   '만나게',
#   '않았기',
#   '믿고',
#   '얻기',
#   '다니는',
#   '이르고',
#   '일컫는',
#   '가면',
#   '되지만',
#   '바꾸어',
#   '않을까',
#   '죽이고',
#   '그러자',
#   '않아서',
#   '살던',
#   '남아있다',
#   '지어',
#   '이루어지고',
#   '꺾고',
#   '않아도',
#   '낳았다',
#   '넣고',
#   '맡게',
#   '되었을',
#   '쓰기',
#   '하니',
#   '맞추어',
#   '살았다',
#   '이루어',
#   '정하는',
#   '불리고',
#   '내고',
#   '되어야',
#   '않았으나',
#   '지어진',
#   '둘러싸고',
#   '받았으나',
#   '알지',
#   '얻고',
#   '않았다고',
#   '넣은',
#   '살아',
#   '나가는',
#   '얻는다',
#   '받기',
#   '두는',
#   '일어나자',
#   '되었습니다',
#   '보시면',
#   '만나는',
#   '인정받아',
#   '남기고',
#   '남아있는',
#   '지고',
#   '잡아',
#   '짓고',
#   '않으나',
#   '두어',
#   '이루어지지',
#   '지키는',
#   '열어',
#   '이루어지는',
#   '열고',
#   '밝히고',
#   '되도록',
#   '일컫는다',
#   '되돌리기',
#   '찾아서',
#   '넣는',
#   '나오고',
#   '알리는',
#   '찍은',
#   '맞고',
#   '입구',
#   '이루었다',
#   '읽고',
#   '되었다가',
#   '빛나는',
#   '맡았으며',
#   '하라',
#   '불리게',
#   '넣었다',
#   '맡았고',
#   '가고',
#   '거느리고',
#   '바꾸고',
#   '잡은',
#   '되어있다',
#   '쓰면',
#   '힘입어',
#   '파리의',
#   '피하기',
#   '올리고',
#   '가지며',
#   '싸우는',
#   '얻지',
#   '하도록',
#   '않는다면',
#   '모르겠네요',
#   '잃었다',
#   '누르고',
#   '느끼고',
#   '지나면서',
#   '카고',
#   '속하며',
#   '지키고',
#   '되었던',
#   '않나요',
#   '보게',
#   '취하고',
#   '보고서',
#   '그러던',
#   '틀의',
#   '드는',
#   '되었다는',
#   '막는',
#   '겪었다',
#   '하는지',
#   '오지',
#   '낳은',
#   '붙이는',
#   '구하는',
#   '일어나고',
#   '향하는',
#   '먹을',
#   '모르고',
#   '주시면',
#   '보이기',
#   '않다는',
#   '당하고',
#   '이끌어',
#   '달고',
#   '않았다는',
#   '오고',
#   '접하며',
#   '치고',
#   '쌓은',
#   '미치지',
#   '보내고',
#   '하네요',
#   '맞습니다',
#   '통틀어',
#   '믿을',
#   '살았던',
#   '일어나지',
#   '가리지',
#   '지키기',
#   '믿는',
#   '만들어서',
#   '비하여',
#   '받아야',
#   '하려고',
#   '나타내고',
#   '지어졌다',
#   '보이지만',
#   '달라고',
#   '닮은',
#   '오리건',
#   '갖지',
#   '제치고',
#   '띠고',
#   '하였지만',
#   '놓았다',
#   '않으므로',
#   '그러다가',
#   '나누는',
#   '끌고',
#   '맺은',
#   '되므로',
#   '읽을',
#   '받았지만',
#   '잡는',
#   '넘게',
#   '걸리는',
#   '구하기',
#   '행하는',
#   '느끼는',
#   '앉아',
#   '지나는',
#   '정하고',
#   '가리는',
#   '흐르고',
#   '끌었다',
#   '치는',
#   '맞은',
#   '쓰이지',
#   '듣지',
#   '바뀌어',
#   '잡았다',
#   '이루며',
#   '붙었다',
#   '받았다고',
#   '되어서',
#   '하므로',
#   '않자',
#   '쓰기도',
#   '맡는',
#   '나타나고',
#   '지나면',
#   '만들어져',
#   '들어오는',
#   '바라는',
#   '뒤의',
#   '가기',
#   '하였습니다',
#   '모르겠지만',
#   '남게',
#   '들지',
#   '가지지',
#   '죽게',
#   '보며',
#   '돌고',
#   '말미암아',
#   '맡았던',
#   '죽는다',
#   '들의',
#   '따르고',
#   '가야',
#   '안고',
#   '않았을',
#   '보이게',
#   '쌓아',
#   '되던',
#   '서서',
#   '남면',
#   '들어가게',
#   '오르는',
#   '내리고',
#   '걸고',
#   '뛰었다',
#   '돕는',
#   '가자',
#   '걸어',
#   '찾지',
#   '알기',
#   '잃게',
#   '보내어',
#   '물리치고',
#   '나타나지',
#   '겪고',
#   '찾고',
#   '않거나',
#   '따르지',
#   '넣을',
#   '짓는',
#   '돌아가는',
#   '마시고',
#   '모시고',
#   '입는',
#   '받아서',
#   '돕기',
#   '즐기는',
#   '세우는',
#   '하야시',
#   '이르게',
#   '당하는',
#   '높이기',
#   '만들어진다',
#   '느끼게',
#   '살펴보면',
#   '죽기',
#   '더불어민주당',
#   '보아야',
#   '만들었고',
#   '주셨으면',
#   '받아들이지',
#   '않았는데',
#   '만들어낸',
#   '살게',
#   '내어',
#   '바뀌는',
#   '하겠다',
#   '배우고',
#   '맡는다',
#   '나오게',
#   '부르게',
#   '벌이는',
#   '듣는',
#   '묻는',
#   '살아남은',
#   '오라',
#   '죽는',
#   '잡을',
#   '보면서',
#   '다니며',
#   '지내는',
#   '누르면',
#   '옮기는',
#   '가르치는',
#   '만들지',
#   '일으키고',
#   '막고',
#   '묶어',
#   '받았던',
#   '기리기',
#   '쓰게',
#   '개이다',
#   '겪은',
#   '않네요',
#   '죽이는',
#   '담아',
#   '끼고',
#   '받으면서',
#   '하기로',
#   '맡기도',
#   '비추어',
#   '보이는데',
#   '보기도',
#   '벌어지는',
#   '떠나는',
#   '통하는',
#   '뛰는',
#   '변하는',
#   '가던',
#   '뻗어',
#   '하려는',
#   '사라지고',
#   '남기지',
#   '믿었다',
#   '돌아오는',
#   '놓는',
#   '만나고',
#   '받았는데',
#   '삼는',
#   '연이어',
#   '변하지',
#   '사서',
#   '넘치는',
#   '읽어',
#   '않습니까',
#   '잊지',
#   '나면',
#   '거치면서',
#   '맺어',
#   '이기고',
#   '듣기',
#   '취하는',
#   '뽑은',
#   '밝히는',
#   '싣고',
#   '속하게',
#   '뚫고',
#   '되다',
#   '미루어',
#   '보세요',
#   '만들어지는',
#   '보이기도',
#   '시키는',
#   '맞았다',
#   '하실',
#   '죽어',
#   '않나',
#   '대하여는',
#   '빠지게',
#   '되나요',
#   '나오는데',
#   '오면',
#   '던지는',
#   '믿지',
#   '자라는',
#   '보았을',
#   '줄이기',
#   '바뀌게',
#   '꿈꾸는',
#   '살아가는',
#   '지나가는',
#   '주었고',
#   '하였다고',
#   '가다',
#   '이루지',
#   '보기에는',
#   '줄어들었다',
#   '벌이고',
#   '주어지는',
#   '거치지',
#   '오게',
#   '깨닫고',
#   '이어지고',
#   '남았다',
#   '들어가서',
#   '향하여',
#   '그만두고',
#   '기다리고',
#   '오기',
#   '믿는다',
#   '살면서',
#   '않겠습니다',
#   '움직이지',
#   '하는게',
#   '그러다',
#   '춤추는',
#   '비하면',
#   '숨어',
#   '내놓았다',
#   '내려오는',
#   '만들게',
#   '넘어서',
#   '낳는다',
#   '입어',
#   '열리고',
#   '만들기도',
#   '불리던',
#   '겪게',
#   '늙은',
#   '섞어',
#   '나누고',
#   '주며',
#   '당하여',
#   '옮기고',
#   '줄이는',
#   '아시겠지만',
#   '들어서면서',
#   '살며',
#   '휘는',
#   '들어있는',
#   '줄이고',
#   '떠나게',
#   '알리고',
#   '생기게',
#   '어울리지',
#   '만들었으며',
#   '보자',
#   '거두며',
#   '만들어야',
#   '살기',
#   '몰고',
#   '받아들이는',
#   '거두어',
#   '받으면',
#   '만드는데',
#   '삼은',
#   '인정받았다',
#   '삼는다',
#   '달아',
#   '받던',
#   '겪는',
#   '이루어질',
#   '거두고',
#   '다니고',
#   '알아서',
#   '연달아',
#   '쓰이기도',
#   '다스리는',
#   '쓰이며',
#   '깨고',
#   '넘은',
#   '올라가는',
#   '맞다고',
#   '바라보는',
#   '오다와라',
#   '기다리는',
#   '나오며',
#   '찾은',
#   '넘어가는',
#   '일어나기',
#   '내며',
#   '묻고',
#   '하려면',
#   '올리기',
#   '하여야',
#   '숨기기',
#   '물어',
#   '받아들이고',
#   '붙이고',
#   '베어',
#   '만들면',
#   '들어가면',
#   '잡기',
#   '모으는',
#   '없애고',
#   '모으고',
#   '오르게',
#   '동이다',
#   '죽지',
#   '나타내기',
#   '목적의',
#   '마시는',
#   '불리었다',
#   '하고자',
#   '않더라도',
#   '가면서',
#   '넣으면',
#   '빼고',
#   '지나고',
#   '지키지',
#   '주면',
#   '나타나며',
#   '하자는',
#   '나뉘었다',
#   '되었기',
#   '먹은',
#   '얻었고',
#   '속하지',
#   '나타나게',
#   '나서서',
#   '바치는',
#   '알아',
#   '나오기',
#   '넘지',
#   '이루게',
#   '달리고',
#   '쓰던',
#   '들어가지',
#   '나뉘며',
#   '모르지만',
#   '쌓고',
#   '남기는',
#   '넣지',
#   '그러니',
#   '남는',
#   '입는다',
#   '떨어지고',
#   '보기에',
#   '알아야',
#   '빼앗아',
#   '하셨는데',
#   '나오면',
#   '인정받고',
#   '뇌의',
#   '모르겠습니다만',
#   '붙는',
#   '보았습니다',
#   '풀어',
#   '않는데',
#   '뽑아',
#   '겹치는',
#   '오르고',
#   '앓고',
#   '보이네요',
#   '쓰며',
#   '들어서는',
#   '지을',
#   '짓을',
#   '죽었고',
#   '뽑는',
#   '나고',
#   '살다가',
#   '듣게',
#   '배우기',
#   '보니까',
#   '어긋나는',
#   '노리고',
#   '알리기',
#   '돌아',
#   '보신',
#   '않기로',
#   '지내다가',
#   '일어나게',
#   '바뀌지',
#   '만들어졌으며',
#   '하죠',
#   '되거나',
#   '숨기고',
#   '바뀌고',
#   '만들어내는',
#   '밝히지',
#   '몰아내고',
#   '먹기도',
#   '않다면',
#   '웃는',
#   '걷는',
#   '만나서',
#   '쏘아',
#   '몰아',
#   '되는지',
#   '찾는다',
#   '줄의',
#   '높이의',
#   '쥐고',
#   '되기를',
#   '읽어보기',
#   '만들었는데',
#   '떠나서',
#   '생기고',
#   '끌어',
#   '늘어나는',
#   '놀라게',
#   '나가지',
#   '벗어나지',
#   '접하는',
#   '낳고',
#   '고치고',
#   '어울리는',
#   '가르치고',
#   '하여도',
#   '데다가',
#   '그러면서',
#   '거두었고',
#   '말아야',
#   '가하는',
#   '않겠다고',
#   '돌아오지',
#   '거두지',
#   '먹지',
#   '바뀌었고',
#   '남아있지',
#   '늘어나고',
#   '나타나기',
#   '받았다는',
#   '나오기도',
#   '물었다',
#   '막아',
#   '사라지게',
#   '오르지',
#   '걸었다',
#   '팔아',
#   '일었다',
#   '하였던',
#   '않았다면',
#   '가져오는',
#   '받았을',
#   '내놓은',
#   '뛰어',
#   '이르러서는',
#   '응하지',
#   '하시면',
#   '피고',
#   '않으면서',
#   '읽은',
#   '다루었다',
#   '떠나고',
#   '치르게',
#   '생겨나는',
#   '끊이지',
#   '튀니지의',
#   '넣어서',
#   '죽이려',
#   '돕는다',
#   '잃어',
#   '떠오르는',
#   '자라고',
#   '가수다',
#   '앙카라',
#   '속하고',
#   '펼치고',
#   '않고도',
#   '하려',
#   '갖추게',
#   '펼치는',
#   '통하지',
#   '가리키며',
#   '잡지의',
#   '키우는',
#   '나타내며',
#   '높이고',
#   '가로지르는',
#   '이기는',
#   '띄고',
#   '느끼지',
#   '이어받아',
#   '싸우고',
#   '뜨는',
#   '보아도',
#   '끼치는',
#   '솟아',
#   '돕고',
#   '않아야',
#   '치르고',
#   '모르겠군요',
#   '만들었다고',
#   '닮았다',
#   '만들며',
#   '읽는다',
#   '묻자',
#   '오자',
#   '줄어들고',
#   '않음을',
#   '다니던',
#   '들자면',
#   '맺게',
#   '얻었으며',
#   '잃지',
#   '올라오는',
#   '갖추었다',
#   '주어야',
#   '칭하고',
#   '띄게',
#   '되어있는',
#   '그치지',
#   '쓰이게',
#   '오르기도',
#   '않았으므로',
#   '듣는다',
#   '되나',
#   '죽었다고',
#   '부르는데',
#   '의식의',
#   '찾았다',
#   '구하고',
#   '끄는',
#   '올리지',
#   '이루어지며',
#   '내었다',
#   '갖추어',
#   '하는가',
#   '하세요',
#   '되어서야',
#   '생기면',
#   '알겠습니다',
#   '나뉘는데',
#   '지우고',
#   '번갈아',
#   '넣으며',
#   '만들어냈다',
#   '이루어졌으며',
#   '모르게',
#   '바뀌면서',
#   '보기는',
#   '들어가고',
#   '놓는다',
#   '넘는다',
#   '맺는',
#   '들어가기',
#   '향하고',
#   '넣는다',
#   '드러내는',
#   '이끌었고',
#   '맞추는',
#   '맡기고',
#   '맞추기',
#   '입게',
#   '만들었습니다',
#   '두었고',
#   '오슈',
#   '멈추지',
#   '싸우게',
#   '만들어지고',
#   '덮고',
#   '먹으면',
#   '빠지고',
#   '겨루는',
#   '자라며',
#   '남아있던',
#   '살리기',
#   '드리는',
#   '이기지',
#   '대고',
#   ...],
#  ['became.',
#   'do',
#   'view',
#   'living',
#   'after',
#   'did.',
#   'but',
#   'to become',
#   'with',
#   'instead of',
#   'not',
#   'becoming',
#   'i got it.',
#   'so',
#   "didn't",
#   "i don't",
#   'according to',
#   'becomes',
#   'summer solstice',
#   'do',
#   'lift it',
#   'take it',
#   'for.',
#   'received',
#   'about',
#   'to see',
#   'receive',
#   'report',
#   'do',
#   'became',
#   'leave it',
#   'if you look at it',
#   'take',
#   "i don't",
#   'know',
#   "you can do it's",
#   'down for the long count',
#   'make',
#   'by',
#   'giving',
#   'called',
#   'not',
#   'if you do',
#   "i don't",
#   'making',
#   'according to',
#   'took charge',
#   'going',
#   'stay',
#   'summer',
#   'pointing',
#   'coming out',
#   'writing',
#   'along with',
#   'i do',
#   'to it',
#   'viewing',
#   'visible',
#   'done',
#   'living',
#   'through',
#   'when it becomes',
#   'receiving',
#   'due to',
#   'while',
#   'gave',
#   'closing',
#   'made.',
#   'sleeping',
#   'living',
#   'take charge of',
#   'as it became',
#   'leading',
#   'used',
#   'write',
#   'by',
#   'receive',
#   'calling',
#   'and',
#   'lead',
#   'representing',
#   'leading to',
#   "let's do it",
#   'and not',
#   'if not',
#   'become',
#   'connecting',
#   'to receive',
#   'to know',
#   'go and',
#   'branches',
#   'so as not',
#   'got',
#   'but',
#   'remaining',
#   'to receive',
#   'over',
#   "let's be",
#   'tour',
#   "i didn't",
#   'ended up',
#   'listen',
#   'boa',
#   'and',
#   'see',
#   'height',
#   'let go',
#   'having',
#   'but',
#   'receive',
#   'holding',
#   'make',
#   'if you lift',
#   'give',
#   'to be gained',
#   'the main road',
#   'obtained',
#   'it works.',
#   'changed',
#   'carry',
#   'dead.',
#   'appearing',
#   'bonnie',
#   'happening',
#   'in charge',
#   'received',
#   'dealing with',
#   'diagram',
#   'to achievement',
#   'even if',
#   'left',
#   'warehousing',
#   'becoming',
#   'made',
#   'coming',
#   'take it',
#   'find',
#   'equipped',
#   'making',
#   'not to',
#   'came true',
#   'get',
#   'divide',
#   'right',
#   'achieving',
#   'ahead of',
#   'namgu',
#   'received',
#   'unaware',
#   'right.',
#   'came to',
#   'gathered',
#   'right',
#   'after picking',
#   'i saw it.',
#   'on the road',
#   'knowing',
#   'kagoshima',
#   'evening',
#   'about',
#   'you can be seen',
#   'i will do that',
#   'prevent',
#   'put it',
#   'opening',
#   'divided',
#   'by the time',
#   'to have',
#   'to find',
#   'light',
#   'grab',
#   'have',
#   'used to',
#   'even to call',
#   'flowing',
#   "wouldn't it be?",
#   'riding',
#   "it's done.",
#   'so as not to',
#   'looking for',
#   'eating',
#   'over',
#   'correctly',
#   'or',
#   "let's die",
#   'but not',
#   'make',
#   'became',
#   'while doing',
#   'contained',
#   'that had not',
#   'find',
#   'led',
#   'ensuing',
#   'write',
#   'put it in',
#   'to die',
#   'dealing',
#   'branched',
#   'became but',
#   'lose',
#   'called',
#   'gina',
#   'arising',
#   'stick together',
#   'after encounters',
#   'get',
#   'receiving',
#   'finish',
#   'in appearance',
#   'by using',
#   "that you don't",
#   'following',
#   'with',
#   'by listening',
#   "i'lllllllllllll",
#   'reading',
#   "you didn't",
#   'it is also called',
#   'not',
#   'throw away',
#   'used and',
#   'vulva',
#   'all the way up to',
#   'going in',
#   'stand up',
#   "i don't know",
#   'staying',
#   'i made',
#   'concluded',
#   'moving',
#   'come out',
#   'lost',
#   'getting',
#   'i wore it.',
#   'causing',
#   'eat.',
#   'sending',
#   'of life',
#   'crazy',
#   'reading',
#   'opened',
#   'attached',
#   'running',
#   'not really',
#   'die',
#   "no, it's not.",
#   'raising',
#   'receive as well',
#   'by making',
#   "it's done,",
#   'changed',
#   'built',
#   'then',
#   'heart.',
#   'changing',
#   'i did',
#   'call',
#   'singing',
#   'laid down',
#   "i didn't",
#   'eat',
#   'falling',
#   'to meet',
#   "didn't",
#   'belie',
#   'obtaining',
#   'going around',
#   'early',
#   'referred to as',
#   'mask',
#   'but',
#   'in other words',
#   "wouldn't it be",
#   'kill',
#   "let's do that.",
#   "because it wasn't",
#   'lived',
#   'left.',
#   'build',
#   'comes true',
#   'deflect',
#   "even if you don't have to",
#   'gave birth',
#   'put it in',
#   'take charge',
#   'would have been',
#   'writing',
#   'hani',
#   'in alignment',
#   'lived',
#   'make it happen',
#   'determined',
#   'called',
#   'pay',
#   'it has to',
#   'but not',
#   'built',
#   'surrounding',
#   'received but',
#   'i know',
#   'get',
#   "that you didn't",
#   'put in',
#   'live',
#   'outgoing',
#   'get',
#   'receive',
#   'leaving',
#   "let's get up",
#   'became.',
#   'as you can see,',
#   'meeting',
#   'in recognition',
#   'leave behind',
#   'remaining',
#   'lose',
#   'catch',
#   'build',
#   'but not',
#   'a couple of',
#   'comes true',
#   'guarding',
#   'open',
#   'accomplished',
#   'open',
#   'reveal',
#   'as much as possible',
#   "it's called",
#   'revert',
#   'find',
#   'putting in',
#   'come out',
#   'informing',
#   'photographed',
#   'right',
#   'entrance',
#   'achieved',
#   'read and',
#   'after being',
#   'shining',
#   'i took charge',
#   'do',
#   'so called',
#   'i put it in.',
#   "i'm in charge.",
#   'go away',
#   "at one's beck and call",
#   'change',
#   'caught',
#   'to be',
#   'if you write',
#   'on the back of',
#   'paris',
#   'avoid',
#   'raise',
#   'to have',
#   'fighting',
#   'get',
#   'so that',
#   "if you don't",
#   "i don't know.",
#   'lost',
#   'press and',
#   'feeling',
#   'as time goes by',
#   'cargo',
#   'belong to',
#   'protect',
#   'whether or become',
#   "isn't it",
#   'see',
#   'drunk',
#   'report',
#   'then',
#   'molded',
#   'lifting',
#   'became',
#   'blocking',
#   'went through',
#   'whether',
#   'ozzy',
#   'spawned',
#   'attaching',
#   'seeking',
#   'rise and shine',
#   'heading',
#   'to eat',
#   'without knowing',
#   'if you give it to me',
#   'show',
#   'not saying',
#   'get hit',
#   'lead',
#   'sweet',
#   "that you didn't",
#   'come',
#   'encountering',
#   'hit',
#   'piled up',
#   'crazy',
#   'send',
#   "you're doing it.",
#   "that's right.",
#   'in total',
#   'to believe',
#   'lived',
#   'happens',
#   'to cover',
#   'protect',
#   'believing',
#   'by making',
#   'compared to',
#   'you have to receive',
#   'to do',
#   'indicate',
#   'built',
#   'although you can see it',
#   'to give',
#   'resembling',
#   'oregon',
#   'have',
#   'over',
#   'on the tip of salt',
#   'but',
#   'i let go',
#   'because',
#   'then',
#   'dividing',
#   'dragging',
#   'made',
#   'as it becomes',
#   'to read',
#   'received but',
#   'catching',
#   'over',
#   'caught',
#   'save',
#   'doing',
#   'feeling',
#   'sit down',
#   'passing',
#   'to decide',
#   'masking',
#   'flowing',
#   'dragged',
#   'hitting',
#   'hit',
#   "it'",
#   'listen',
#   'changed',
#   'i got it.',
#   'accomplishing',
#   'got stuck',
#   'i got it.',
#   'becoming',
#   'because',
#   "when i didn't",
#   'writing too',
#   'in charge',
#   'appears',
#   'after',
#   'made',
#   'incoming',
#   'desired',
#   'behind',
#   'go',
#   'did.',
#   "i don't know.",
#   'remain',
#   'lift up',
#   'have',
#   'to die',
#   'looking',
#   'round and round',
#   'at the end of',
#   'in charge of',
#   'die.',
#   'field',
#   'follow',
#   'i gotta go',
#   'hugging',
#   "wouldn't have",
#   'to be seen',
#   'stack',
#   'used to be',
#   'standing',
#   'remaining side',
#   'to go in',
#   'climbing',
#   'get off',
#   'betting',
#   'jumped',
#   'helping',
#   "let's go",
#   'walk.',
#   'looking for',
#   'knowing',
#   'to lose',
#   'send it',
#   'defeat',
#   'appear',
#   'going through',
#   'find and',
#   'or not',
#   'follow',
#   'to put in',
#   'building',
#   'going back',
#   'drink',
#   'with',
#   'worn',
#   'to receive',
#   'help',
#   'enjoying',
#   'building',
#   'hayashi',
#   'early',
#   'being subjected',
#   'raising',
#   'to be made',
#   'feel',
#   'if you look at it,',
#   'to die',
#   'the minjoo party',
#   'to see',
#   'i made it.',
#   "if you'd give it to me,",
#   "i'll take it.",
#   "i didn't.",
#   'created',
#   'live',
#   'to give',
#   'changing',
#   "i'll do it.",
#   'learn and',
#   'take charge',
#   'come out',
#   'call me',
#   'waging',
#   'listening',
#   'asking',
#   'surviving',
#   'come',
#   'dying',
#   'to catch',
#   'while watching',
#   'going around',
#   'staying',
#   'press',
#   'moving',
#   'teaching',
#   'create',
#   'raising',
#   'block',
#   'tie up',
#   'received',
#   'honoring',
#   'use',
#   'to be a dog',
#   'experienced',
#   "it's not",
#   'killing',
#   'put it in',
#   'with',
#   'as you receive',
#   'to do',
#   'take charge',
#   'in light',
#   'i can see it.',
#   'view also',
#   'happening',
#   'leaving',
#   'communicating',
#   'running',
#   'changing',
#   'going',
#   'stretch out',
#   'to do',
#   'disappear',
#   'leave',
#   'believed',
#   'returning',
#   'letting go',
#   'meet',
#   'i got it.',
#   'using',
#   'one after another',
#   'change',
#   'librarian',
#   'overflowing',
#   'read',
#   "isn't it",
#   'forget',
#   "when it's over",
#   'as it goes through',
#   'conclude',
#   'win',
#   'listening',
#   'intoxicated',
#   'plucked',
#   'revealing',
#   'loaded',
#   'belong to',
#   'through',
#   'become',
#   'procrastinate',
#   'look.',
#   'being made',
#   'to be seen',
#   'ordered',
#   'got hit',
#   'to do',
#   'die',
#   "isn't it",
#   'as for',
#   'to soak up',
#   'does it work',
#   "it's coming out.",
#   'if you come',
#   'throwing',
#   'i believe it',
#   'growing',
#   'would have seen',
#   'reduce',
#   'to change',
#   'dreaming',
#   'living',
#   'passing by',
#   'i gave it to him.',
#   'i did',
#   'go',
#   'accomplish',
#   'on the face of it',
#   'shrank',
#   'overdoing',
#   'given',
#   'go through',
#   'come on',
#   'realizing',
#   'continuing',
#   'left.',
#   'go in',
#   'toward',
#   'quit',
#   'waiting',
#   'a lapse of the pen',
#   'believe.',
#   "in one's life",
#   "i won't.",
#   "it's moving.",
#   "it's because",
#   'then',
#   'dancing',
#   'compared to',
#   'hide',
#   'put out',
#   'descending',
#   "i'll make it",
#   'beyond',
#   'to give birth',
#   'put it',
#   'open up',
#   'create also',
#   'called',
#   'to suffer',
#   'old',
#   'mix',
#   'divide',
#   'giving',
#   'being subjected to',
#   'move',
#   'reducing',
#   'as you know,',
#   'as you walk in',
#   "in one's life",
#   'bending',
#   'contained',
#   'reduce',
#   'leave',
#   'inform',
#   'so that',
#   'to fit in',
#   'created and',
#   'see you',
#   'collecting',
#   'you have to make it',
#   'living',
#   'driving',
#   'accepting',
#   'collect',
#   'when i receive',
#   'to make',
#   'taken',
#   'was recognized',
#   'i use',
#   'sweet',
#   'received',
#   'going through',
#   'to be achieved',
#   'reaping',
#   'go around',
#   'because i know',
#   'one after another',
#   'to be used',
#   'ruling',
#   'being used',
#   'wake up',
#   'over',
#   'going up',
#   "that's right.",
#   'looking',
#   'come and see me.',
#   'waiting',
#   'coming out',
#   'found',
#   'falling over',
#   'getting up',
#   'with',
#   'asking',
#   'to do',
#   'raising',
#   'to do',
#   'hide',
#   'bite',
#   'accept',
#   'attach',
#   'bear',
#   'if you make',
#   'when you go in',
#   'catch',
#   'gathering',
#   'get rid of',
#   'gather',
#   'up',
#   'to be frozen',
#   'dying',
#   'indicate',
#   'purposeful',
#   'drinking',
#   'was called',
#   'to',
#   "even if you don't",
#   'on the way',
#   'if you put it in,',
#   'except',
#   'after',
#   'keep it',
#   'if you give it to me',
#   'appearing',
#   'to do',
#   'divided',
#   'became',
#   'ate',
#   'i got it',
#   'belong',
#   'show up',
#   'step up and',
#   'offering',
#   'i know',
#   'coming out',
#   'over',
#   'to achieve',
#   'running',
#   'used',
#   'get in',
#   'divided',
#   "i don't know.",
#   'stack up',
#   'leaving',
#   'put in',
#   'so',
#   'remaining',
#   'wear',
#   'falling off',
#   'in view',
#   'you have to know',
#   'take it away',
#   'you did.',
#   'when it comes out',
#   'to be recognized',
#   'brain',
#   "i don't know.",
#   'sticking',
#   "i've seen",
#   'unscrew',
#   "i don't",
#   'pull it out',
#   'overlapping',
#   'up',
#   'suffering',
#   'i see it.',
#   'while writing',
#   'in the',
#   'to build',
#   'to do something',
#   'dead.',
#   'to pick',
#   "i'm me",
#   "in one's life",
#   'listen to me.',
#   'learning',
#   'looking at it,',
#   'out of place',
#   'aim for',
#   'inform',
#   'turn around',
#   'seen',
#   'not to',
#   'after living',
#   'to wake up',
#   'it changes',
#   'created and',
#   "i'll do it.",
#   'either',
#   'hide',
#   'changed',
#   'creating',
#   'reveal',
#   'drive out',
#   'eating too',
#   'if not',
#   'smiling',
#   'walking',
#   'meet',
#   'shoot',
#   'drive',
#   'is it possible',
#   'look for',
#   'rowed',
#   'high',
#   'may',
#   'read it',
#   'i made it.',
#   'leaving',
#   'comes into being',
#   'drag',
#   'increasing',
#   'surprised',
#   'get out',
#   'deviations',
#   'encountered',
#   'giving birth to',
#   'fix it',
#   'matching',
#   'teaching',
#   'nevertheless',
#   'plus',
#   'by doing that',
#   'i collected',
#   'should not',
#   'inflically',
#   "i won't do it.",
#   'come back',
#   "i'll take it.",
#   'eat',
#   'changed and',
#   "it's left",
#   'increasing',
#   'appearing',
#   'received',
#   'come out too',
#   'asked',
#   'stop',
#   'disappear',
#   'climb',
#   'walked',
#   'sell',
#   'rose',
#   'did',
#   'if not',
#   'importing',
#   'received',
#   'put out',
#   'run',
#   'in the end',
#   "i'll take it.",
#   'if you do',
#   'defendant',
#   'without',
#   'read',
#   'dealt with',
#   'leaving',
#   'pay',
#   'arising',
#   'ceaseless',
#   'tunisian',
#   'by putting',
#   'to kill',
#   'help',
#   'lose',
#   'rising',
#   'go to sleep',
#   'to be a singer',
#   'ankara woolen collar',
#   'belong to',
#   'spread out',
#   'without having to',
#   'to do',
#   'to be equipped',
#   'unfolding',
#   'through',
#   'pointing',
#   'magazine',
#   'raising',
#   'indicating',
#   'increase',
#   'crossing',
#   'winning',
#   'spacing out',
#   'feel',
#   'take over',
#   'fight',
#   'floating',
#   'by the looks of it',
#   'causing',
#   'rise up',
#   'help',
#   'should not be',
#   'pay and',
#   "i don't know.",
#   'i made it',
#   'resemble.',
#   'making',
#   'read',
#   "let's ask",
#   "let's come",
#   'diminishing',
#   'not',
#   'used to go',
#   'for example',
#   'make a deal',
#   'obtained and',
#   'losing',
#   'coming up',
#   'have',
#   'to give',
#   'name and',
#   'noticeably',
#   'supposed',
#   'stop',
#   'to be used',
#   'climbing',
#   'because it was not',
#   'hear.',
#   'does it work',
#   'dead.',
#   "i'm singing",
#   'conscious',
#   'found.',
#   'get',
#   'dragging',
#   "i'll post it",
#   'comes true',
#   'paid',
#   'equipped',
#   'do',
#   'do it.',
#   'not until',
#   'when it happens',
#   'all right.',
#   "it's divided.",
#   'erase it.',
#   'alternatively',
#   'putting it in',
#   'created',
#   'was accomplished and',
#   'unknowingly',
#   'as it changes',
#   'views are',
#   'get in',
#   'let go',
#   'to exceed',
#   'concluding',
#   'get in',
#   'toward',
#   'put.',
#   'revealing',
#   'led and',
#   'matching',
#   'leave it to me',
#   'fit',
#   "i'll wear it",
#   'i made it.',
#   'i left it',
#   'oshu',
#   'stop',
#   'fight.',
#   'it is made',
#   'cover',
#   'if you eat',
#   'out',
#   'competing',
#   'growing up',
#   'remaining',
#   'save',
#   'giving',
#   "it's",
#   'on top of',
#   'one after another',
#   ...])

# %%
with open(f'./data/ko_verb_dict(vocab_size-{len(ko_dict)}).pkl', "wb") as fp:
    pickle.dump(ko_dict, fp)

with open(f'./data/en_verb_dict(vocab_size-{len(en_dict)}).pkl', "wb") as fp:
    pickle.dump(en_dict, fp)

# %%
ko_dict
# Out:
# {'하는': array([-0.094249 ,  0.42494  , -0.20604  ,  0.12892  , -0.054444 ,
#          0.18967  ,  0.037641 ,  0.076383 , -0.0017118, -0.055959 ,
#         -0.33836  ,  0.25018  , -0.02257  , -0.030147 ,  0.31057  ,
#          0.29077  ,  0.10817  ,  0.33446  , -0.13597  , -0.15454  ,
#         -0.12388  , -0.027503 ,  0.079178 , -0.18426  ,  0.32628  ,
#          0.078985 ,  0.26358  , -0.054113 , -0.03416  ,  0.33462  ,
#         -0.22894  ,  0.20006  ,  0.1299   , -0.35966  , -0.26735  ,
#         -0.0025038, -0.15737  ,  0.082583 , -0.011795 , -0.17548  ,
#          0.088322 , -0.16427  , -0.36592  , -0.034449 ,  0.16082  ,
#         -0.39021  ,  0.08214  , -0.095953 ,  0.018573 , -0.27027  ,
#          0.15739  ,  0.14677  , -0.1527   , -0.25613  , -0.10433  ,
#         -0.21966  , -0.40082  ,  0.12182  , -0.33762  , -0.064375 ,
#          0.27708  ,  0.17801  ,  0.14884  , -0.095727 ,  0.35548  ,
#          0.12912  ,  0.28289  ,  0.22598  , -0.29775  , -0.31164  ,
#         -0.19424  ,  0.1869   , -0.16078  , -0.19768  , -0.0069544,
#         -0.059183 ,  0.15883  ,  0.14525  ,  0.32778  ,  0.13154  ,
#         -0.0019663,  0.17735  ,  0.032865 ,  0.066497 , -0.15291  ,
#         -0.088507 , -0.10458  , -0.081675 , -0.12562  ,  0.26828  ,
#         -0.054472 ,  0.276    , -0.31567  , -0.025326 ,  0.063433 ,
#          0.17594  ,  0.0075767,  0.087745 ,  0.14237  ,  0.14101  ,
#          0.17619  ,  0.074368 , -0.12097  , -0.1294   , -0.030017 ,
#          0.10627  , -0.041189 ,  0.14953  , -0.0021092, -0.12284  ,
#         -0.20316  ,  0.037785 , -0.33663  , -0.025056 , -0.04529  ,
#         -0.16169  ,  0.17556  ,  0.17782  , -0.36734  ,  0.020121 ,
#         -0.10912  , -0.36288  ,  0.023058 , -0.075148 , -0.12202  ,
#          0.0099005, -0.070888 ,  0.17877  ,  0.46673  ,  0.23777  ,
#         -0.0017048, -0.1244   , -0.22213  ,  0.42356  , -0.18864  ,
#         -0.39434  , -0.072705 ,  0.31144  ,  0.1783   , -0.083304 ,
#          0.10304  ,  0.095053 , -0.01893  ,  0.3656   ,  0.023926 ,
#          0.19711  ,  0.080087 , -0.25798  , -0.38155  , -0.22142  ,
#         -0.33792  ,  0.13724  ,  0.0024435,  0.10864  , -0.073616 ,
#         -0.057572 , -0.06336  ,  0.31613  , -0.057557 ,  0.18735  ,
#         -0.047333 ,  0.29057  , -0.13794  , -0.0079186,  0.33025  ,
